# %%
import xarray as xr

# %%
ds = xr.open_dataset("/home/slama/Documents/lstm/data/usgs-streamflow-nldas_hourly.nc")

# %%
ds["basin"].values
# Out:
# array(['02064000', '01547700', '03015500', '01022500'], dtype='<U8')

# %%
from lstm.run_lstm_with_bmi_v2 import *

execute()
# Out:
# Creating an instance of an BMI_LSTM model object...
# Initializing the BMI...
# Get input data that matches the LSTM test runs...
# Loop through the inputs, set the forcing values, and update the model...
#   temperature and precipitation are set to 9.79 and 0.00
#   streamflow (CMS) at time 1 is <lstm.model_state.State object at 0x7f1c5ae95310>
#   temperature and precipitation are set to 9.14 and 0.00
#   streamflow (CMS) at time 2 is <lstm.model_state.State object at 0x7f1c5ae95310>
#   temperature and precipitation are set to 8.49 and 0.00
#   streamflow (CMS) at time 3 is <lstm.model_state.State object at 0x7f1c5ae95310>
#   temperature and precipitation are set to 7.84 and 0.00
#   streamflow (CMS) at time 4 is <lstm.model_state.State object at 0x7f1c5ae95310>
#   temperature and precipitation are set to 7.04 and 0.00
#   streamflow (CMS) at time 5 is <lstm.model_state.State object at 0x7f1c5ae95310>
#   temperature and precipitation are set to 6.23 and 0.00
# ...
